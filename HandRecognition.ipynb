# %%
import cv2

# %%
# %%cmd
# where python
# Out:
# Microsoft Windows [Version 10.0.19045.4474]
# (c) Microsoft Corporation. All rights reserved.
#
# (base) C:\Users\Admin\Downloads>where python
# C:\Users\Admin\Anaconda\python.exe
# C:\Users\Admin\AppData\Local\Programs\Python\Python312\python.exe
# C:\Users\Admin\AppData\Local\Microsoft\WindowsApps\python.exe
#
# (base) C:\Users\Admin\Downloads>

# %%
# %%cmd
# pip install cmake
# Out:
# Microsoft Windows [Version 10.0.19045.4474]
# (c) Microsoft Corporation. All rights reserved.
#
# (base) C:\Users\Admin\Downloads>pip install cmake
# ...
#    ---------------------------------------- 35.7/35.7 MB 3.4 MB/s eta 0:00:004
# ...
#
# (base) C:\Users\Admin\Downloads>

# %%
# %%cmd
# python --version
# Out:
# Microsoft Windows [Version 10.0.19045.4474]
# (c) Microsoft Corporation. All rights reserved.
#
# (base) C:\Users\Admin\Downloads>python --version
# Python 3.12.4
#
# (base) C:\Users\Admin\Downloads>

# %%
# %pip install mediapipe opencv-python --user
# Out:
# ...
#   Using cached mediapipe-0.10.14-cp312-cp312-win_amd64.whl.metadata (9.9 kB)
# ...
#   Using cached jax-0.4.30-py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached jaxlib-0.4.30-cp312-cp312-win_amd64.whl.metadata (1.1 kB)
# ...
#   Using cached opencv_contrib_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached sounddevice-0.4.7-py3-none-win_amd64.whl.metadata (1.4 kB)
# ...
# Using cached mediapipe-0.10.14-cp312-cp312-win_amd64.whl (50.8 MB)
# Using cached sounddevice-0.4.7-py3-none-win_amd64.whl (200 kB)
# Using cached jax-0.4.30-py3-none-any.whl (2.0 MB)
# Using cached jaxlib-0.4.30-cp312-cp312-win_amd64.whl (52.0 MB)
# Using cached opencv_contrib_python-4.10.0.84-cp37-abi3-win_amd64.whl (45.5 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mediapipe as mp
import cv2
import numpy as np
import uuid
import os

# %%
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

# %%
cap = cv2.VideoCapture(0)

with mp_hands.Hands(min_detection_confidence = 0.8, min_tracking_confidence=0.5) as hands: #instantiation of mediapipe hands model
    while cap.isOpened():  #while we're connected to our camera
        ret, frame = cap.read()   #read each frame from our webcam, frame will represent image from our webcam

        #BGR TO RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        #Flip on Horizontal i.e. enable image mirroring
        image=cv2.flip(image, 1)
        
        #Set flag
        image.flags.writeable = False

        #DETECTIONS
        results = hands.process(image)

        #Set flag back to true i.e. allow to render or draw on this image back again 
        image.flags.writeable = True
        
        #RGB to BGR
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        #allow us to see detections
        print(results)

        #Rendering results, checking if we actually have results
        if results.multi_hand_landmarks:
            for num, hand in enumerate(results.multi_hand_landmarks):
                mp_drawing.draw_landmarks(image, hand, mp_hands.HAND_CONNECTIONS#,
                                         #mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                         #mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=4)
                                         )
        
        cv2.imshow("Hand Tracking", image)  #rendering that image to the screeen
    
        if cv2.waitKey(10) & 0xFF == ord('q'):  #if q is pressed or window is closed break out of the loop and stop the feed
            break

cap.release()  #release the webcam
cv2.destroyAllWindows()  #closes the frame
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ...

# %%
os.mkdir('Output Images')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 os.mkdir('Output Images')
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'Output Images'

# %%
cap = cv2.VideoCapture(0)

with mp_hands.Hands(min_detection_confidence = 0.8, min_tracking_confidence=0.5) as hands: #instantiation of mediapipe hands model
    while cap.isOpened():  #while we're connected to our camera
        ret, frame = cap.read()   #read each frame from our webcam, frame will represent image from our webcam

        #BGR TO RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        #Flip on Horizontal i.e. enable image mirroring
        image=cv2.flip(image, 1)
        
        #Set flag
        image.flags.writeable = False

        #DETECTIONS
        results = hands.process(image)

        #Set flag back to true i.e. allow to render or draw on this image back again 
        image.flags.writeable = True
        
        #RGB to BGR
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        #allow us to see detections
        print(results)

        #Rendering results, checking if we actually have results
        if results.multi_hand_landmarks:
            for num, hand in enumerate(results.multi_hand_landmarks):
                mp_drawing.draw_landmarks(image, hand, mp_hands.HAND_CONNECTIONS#,
                                         #mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                         #mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=4)
                                         )

        #Going to save our image
        cv2.imwrite(os.path.join('Output Images','{}.jpg'.format(uuid.uuid())),image)
        
        cv2.imshow("Hand Tracking", image)  #rendering that image to the screeen
    
        if cv2.waitKey(10) & 0xFF == ord('q'):  #if q is pressed or window is closed break out of the loop and stop the feed
            break

cap.release()  #release the webcam
cv2.destroyAllWindows()  #closes the frame
